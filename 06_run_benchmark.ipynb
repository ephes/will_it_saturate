# %%
from will_it_saturate.core import Benchmark
from will_it_saturate.server import FastAPIUvicornServer, NginxDockerServer
from will_it_saturate.client import HttpxClient, AioHttpClient, WrkClient

# %%
# dont_test

byte = 8
gigabit = 10 ** 9
bandwidth = gigabit / byte

# file_sizes = [10 ** 7, 10 ** 6]
file_sizes = [10 ** 7, 10 ** 6, 10 ** 5]
# file_sizes = [10 ** 7]

benchmark = Benchmark(
    bandwidth=bandwidth,
    duration=3,
    file_sizes=file_sizes,
    servers=[NginxDockerServer(), FastAPIUvicornServer()],
    # servers=[NginxDockerServer()],
    clients=[HttpxClient(name="httpx"), AioHttpClient(name="aiohttp"), WrkClient(name="wrk")],
)
benchmark.create_rows()

# %%
# %%time
# dont_test

benchmark.run()
# Out:
# 31951b3a2b948515ab176bbe2ac0d7db9491a2d321ed89b9e9c5297332241fc6
#
# measure
# measure
# measure
# 31951b3a2b94
#
# wis-nginx
#
# measure
# measure
# measure
# CPU times: user 135 ms, sys: 136 ms, total: 272 ms
# Wall time: 2min 44s

# %%
# dont_test

benchmark.results_frame
# Out:
#              server   client  file_size    elapsed  complete_size platform  \
# 0      nginx/docker    httpx   10000000   5.455095      375000000   x86_64
# 1      nginx/docker    httpx    1000000   6.190117      375000000   x86_64
# 2      nginx/docker    httpx     100000  16.346948      375000000   x86_64
# 3      nginx/docker  aiohttp   10000000   6.773724      375000000   x86_64
# 4      nginx/docker  aiohttp    1000000   6.802302      375000000   x86_64
# 5      nginx/docker  aiohttp     100000   9.089199      375000000   x86_64
# 6      nginx/docker      wrk   10000000   0.097556      375000000   x86_64
# 7      nginx/docker      wrk    1000000   4.391017      375000000   x86_64
# 8      nginx/docker      wrk     100000   7.590867      375000000   x86_64
# 9   fastAPI/uvicorn    httpx   10000000   6.968313      375000000   x86_64
# 10  fastAPI/uvicorn    httpx    1000000   7.126479      375000000   x86_64
# 11  fastAPI/uvicorn    httpx     100000  31.009945      375000000   x86_64
# 12  fastAPI/uvicorn  aiohttp   10000000   6.043534      375000000   x86_64
# 13  fastAPI/uvicorn  aiohttp    1000000   5.599293      375000000   x86_64
# 14  fastAPI/uvicorn  aiohttp     100000   9.828979      375000000   x86_64
# 15  fastAPI/uvicorn      wrk   10000000   0.062413      375000000   x86_64
# 16  fastAPI/uvicorn      wrk    1000000   3.363221      375000000   x86_64
# 17  fastAPI/uvicorn      wrk     100000  10.071100      375000000   x86_64
#
#    file_size_h  bytes_per_second bytes_per_second_h
# 0       9.54MB      6.874308e+07            65.56MB
# 1     976.56KB      6.058044e+07            57.77MB
# 2      97.66KB      2.294006e+07            21.88MB
# 3       9.54MB      5.536098e+07             52.8MB
# 4     976.56KB      5.512839e+07            52.57MB
# 5      97.66KB      4.125776e+07            39.35MB
# 6       9.54MB      3.843935e+09             3.58GB
# 7     976.56KB      8.540163e+07            81.45MB
# 8      97.66KB      4.940147e+07            47.11MB
# 9       9.54MB      5.381503e+07            51.32MB
# 10    976.56KB      5.262066e+07            50.18MB
# 11     97.66KB      1.209289e+07            11.53MB
# 12      9.54MB      6.204978e+07            59.18MB
# 13    976.56KB      6.697274e+07            63.87MB
# 14     97.66KB      3.815249e+07            36.39MB
# 15      9.54MB      6.008369e+09              5.6GB
# 16    976.56KB      1.115003e+08           106.33MB
# 17     97.66KB      3.723526e+07            35.51MB

# %%
# dont_test

benchmark.results_frame
# Out:
#          server   client  file_size    elapsed  complete_size platform  \
# 0  nginx/docker    httpx   10000000   5.553751      375000000   x86_64
# 1  nginx/docker    httpx    1000000   6.163784      375000000   x86_64
# 2  nginx/docker    httpx     100000  16.741714      375000000   x86_64
# 3  nginx/docker  aiohttp   10000000   6.226602      375000000   x86_64
# 4  nginx/docker  aiohttp    1000000   6.590626      375000000   x86_64
# 5  nginx/docker  aiohttp     100000   9.769070      375000000   x86_64
# 6  nginx/docker      wrk   10000000   0.071795      375000000   x86_64
# 7  nginx/docker      wrk    1000000   4.713399      375000000   x86_64
# 8  nginx/docker      wrk     100000   7.987198      375000000   x86_64
#
#   file_size_h  bytes_per_second bytes_per_second_h
# 0      9.54MB      6.752193e+07            64.39MB
# 1    976.56KB      6.083925e+07            58.02MB
# 2     97.66KB      2.239914e+07            21.36MB
# 3      9.54MB      6.022546e+07            57.44MB
# 4    976.56KB      5.689900e+07            54.26MB
# 5     97.66KB      3.838646e+07            36.61MB
# 6      9.54MB      5.223224e+09             4.86GB
# 7    976.56KB      7.956041e+07            75.87MB
# 8     97.66KB      4.695013e+07            44.78MB

# %%
# dont_test

benchmark.results_frame
# Out:
#             server   client  file_size    elapsed  complete_size platform  \
# 0  fastAPI/uvicorn    httpx   10000000   5.858320      375000000   x86_64
# 1  fastAPI/uvicorn    httpx    1000000   6.366118      375000000   x86_64
# 2  fastAPI/uvicorn    httpx     100000  29.733322      375000000   x86_64
# 3  fastAPI/uvicorn  aiohttp   10000000   6.536370      375000000   x86_64
# 4  fastAPI/uvicorn  aiohttp    1000000   5.472619      375000000   x86_64
# 5  fastAPI/uvicorn  aiohttp     100000   8.756721      375000000   x86_64
# 6  fastAPI/uvicorn      wrk   10000000   0.055350      375000000   x86_64
# 7  fastAPI/uvicorn      wrk    1000000   3.537410      375000000   x86_64
# 8  fastAPI/uvicorn      wrk     100000  10.081593      375000000   x86_64
#
#   file_size_h  bytes_per_second bytes_per_second_h
# 0      9.54MB      6.401152e+07            61.05MB
# 1    976.56KB      5.890560e+07            56.18MB
# 2     97.66KB      1.261211e+07            12.03MB
# 3      9.54MB      5.737129e+07            54.71MB
# 4    976.56KB      6.852294e+07            65.35MB
# 5     97.66KB      4.282425e+07            40.84MB
# 6      9.54MB      6.775082e+09             6.31GB
# 7    976.56KB      1.060098e+08            101.1MB
# 8     97.66KB      3.719650e+07            35.47MB

# %%
# dont_test

benchmark.results_frame
# Out:
#             server   client  file_size    elapsed  complete_size platform  \
# 0  fastAPI/uvicorn    httpx   10000000   6.037067      375000000   x86_64
# 1  fastAPI/uvicorn    httpx    1000000   6.055068      375000000   x86_64
# 2  fastAPI/uvicorn    httpx     100000  29.964979      375000000   x86_64
# 3  fastAPI/uvicorn  aiohttp   10000000   5.628240      375000000   x86_64
# 4  fastAPI/uvicorn  aiohttp    1000000   5.327919      375000000   x86_64
# 5  fastAPI/uvicorn  aiohttp     100000   8.444319      375000000   x86_64
# 6  fastAPI/uvicorn      wrk   10000000   2.772339      375000000   x86_64
# 7  fastAPI/uvicorn      wrk    1000000   7.399281      375000000   x86_64
# 8  fastAPI/uvicorn      wrk     100000   7.345828      375000000   x86_64
#
#   file_size_h  bytes_per_second bytes_per_second_h
# 0      9.54MB      6.211625e+07            59.24MB
# 1    976.56KB      6.193159e+07            59.06MB
# 2     97.66KB      1.251461e+07            11.93MB
# 3      9.54MB      6.662829e+07            63.54MB
# 4    976.56KB      7.038395e+07            67.12MB
# 5     97.66KB      4.440855e+07            42.35MB
# 6      9.54MB      1.352648e+08            129.0MB
# 7    976.56KB      5.068060e+07            48.33MB
# 8     97.66KB      5.104939e+07            48.68MB

# %%
# dont_test

benchmark.results_frame
# Out:
#             server   client  file_size    elapsed  complete_size file_size_h  \
# 0  fastAPI/uvicorn    httpx   10000000   6.212713      375000000      9.54MB
# 1  fastAPI/uvicorn    httpx    1000000   7.464866      375000000    976.56KB
# 2  fastAPI/uvicorn    httpx     100000  30.550003      375000000     97.66KB
# 3  fastAPI/uvicorn  aiohttp   10000000   6.143259      375000000      9.54MB
# 4  fastAPI/uvicorn  aiohttp    1000000   5.936163      375000000    976.56KB
# 5  fastAPI/uvicorn  aiohttp     100000   9.707379      375000000     97.66KB
#
#    bytes_per_second bytes_per_second_h
# 0      6.036010e+07            57.56MB
# 1      5.023533e+07            47.91MB
# 2      1.227496e+07            11.71MB
# 3      6.104252e+07            58.21MB
# 4      6.317212e+07            60.25MB
# 5      3.863041e+07            36.84MB

# %%
# dont_test

benchmark.results_frame
# Out:
#             server   client  file_size    elapsed  complete_size file_size_h  \
# 0  fastAPI/uvicorn    httpx   10000000   7.621326      375000000      9.54MB
# 1  fastAPI/uvicorn    httpx    1000000   8.129900      375000000    976.56KB
# 2  fastAPI/uvicorn    httpx     100000  31.303474      375000000     97.66KB
# 3  fastAPI/uvicorn  aiohttp   10000000   8.092180      375000000      9.54MB
# 4  fastAPI/uvicorn  aiohttp    1000000   6.438935      375000000    976.56KB
# 5  fastAPI/uvicorn  aiohttp     100000   9.158107      375000000     97.66KB
#
#    bytes_per_second bytes_per_second_h
# 0      4.920404e+07            46.92MB
# 1      4.612603e+07            43.99MB
# 2      1.197950e+07            11.42MB
# 3      4.634103e+07            44.19MB
# 4      5.823944e+07            55.54MB
# 5      4.094732e+07            39.05MB

# %%
# dont_test

benchmark.results_frame
# Out:
#             server   client  file_size   elapsed  complete_size file_size_h  \
# 0  fastAPI/uvicorn    httpx   10000000  3.325116      375000000      9.54MB
# 1  fastAPI/uvicorn    httpx    1000000  3.553887      375000000    976.56KB
# 2  fastAPI/uvicorn    httpx     100000  6.097791      375000000     97.66KB
# 3  fastAPI/uvicorn  aiohttp   10000000  3.505289      375000000      9.54MB
# 4  fastAPI/uvicorn  aiohttp    1000000  3.478566      375000000    976.56KB
# 5  fastAPI/uvicorn  aiohttp     100000  4.947546      375000000     97.66KB
#
#    bytes_per_second bytes_per_second_h
# 0      1.127780e+08           107.55MB
# 1      1.055183e+08           100.63MB
# 2      6.149768e+07            58.65MB
# 3      1.069812e+08           102.03MB
# 4      1.078030e+08           102.81MB
# 5      7.579515e+07            72.28MB
